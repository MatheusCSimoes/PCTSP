# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

from docplex.mp.model import Model as CplexModel
import docplex.mp.solution as CplexSol

import gurobipy as gb

# %% [markdown]
# ## Leitura dos dados

# %%
xlsx = pd.ExcelFile('Dados trab PO1.xlsx')
df1 = pd.read_excel(xlsx, 'Pontos Turisticos')
df2 = pd.read_excel(xlsx, 'Recompensa por horario', header=None)
df3 = pd.read_excel(xlsx, 'Custo (reais)', header=None)
df4 = pd.read_excel(xlsx, 'Tempo (min)', header=None)

# %%
toy_size = 20
df1 = df1.head(toy_size)
df2 = df2.loc[:toy_size,:]
df3 = df3.loc[:toy_size,:toy_size]
df4 = df4.loc[:toy_size,:toy_size]

# %%
df1
# Out:
#     Id                   Nome  Custo Fixo  Abre - horario  Fecha - horario  \
# 0    1              Corcovado        82.0             8.0             19.0
# 1    2     Mirante Dona Marta         0.0             8.0             17.0
# 2    3          Pão de Açúcar       104.4             8.0             21.0
# 3    4    Forte de Copacabana         6.0            10.0             18.0
# 4    5    Praia de Copacabana         0.0             7.0             19.0
# 5    6      Pedra do Arpoador         0.0             7.0             19.0
# 6    7       Praia de Ipanema         0.0             8.0             17.0
# 7    8      Mirante do Leblon         0.0             7.0             19.0
# 8    9     Parque Dois Irmãos         0.0             8.0             22.0
# 9   10      Morro Dois Irmãos         0.0             7.0             19.0
# 10  11                  Lagoa         0.0             7.0             19.0
# 11  12    Parque da Catacumba         0.0             8.0             17.0
# 12  13        Jardim Botânico        15.0             8.0             18.0
# 13  14     Floresta da Tijuca         0.0             8.0             17.0
# 14  15         Pedra da Gávea         0.0             8.0             17.0
# 15  16           Pedra Bonita         0.0             8.0             17.0
# 16  17      Praia da Joatinga         0.0             7.0             19.0
# 17  18  Museu Nac. Bel. Artes         8.0            10.0             18.0
# 18  19     Mosteiro São Bento         0.0             6.0             18.0
# 19  20      Theatro Municipal         5.0            10.0             18.0
#
#     Permanecia  Avaliacao Preferencia
# 0         2.00        4.5       Tarde
# 1         2.00        4.5       Manha
# 2         2.00        4.5       Tarde
# 3         1.66        4.5       Tarde
# 4         3.00        4.5       Manha
# 5         1.66        4.5       Tarde
# 6         3.00        4.5       Manha
# 7         1.66        4.5       Tarde
# 8         1.66        4.5       Tarde
# 9         3.00        5.0       Manha
# 10        2.00        4.5       Tarde
# 11        2.00        4.5       Manha
# 12        3.00        4.5       Tarde
# 13        4.00        4.5       Manha
# 14        2.00        4.5       Manha
# 15        3.00        5.0       Manha
# 16        4.00        4.5       Manha
# 17        2.00        4.5       Tarde
# 18        2.00        4.5       Manha
# 19        2.00        4.5       Noite

# %%
startingPoint = 4

df1.at[startingPoint,'Abre - horario'] = 0
df1.at[startingPoint,'Fecha - horario'] = 24
df1.at[startingPoint,'Permanecia'] = 0
df1.at[startingPoint,'Custo Fixo'] = 0
df1.at[startingPoint,'Avaliacao'] = 0

# %%
CF = np.asarray(df1['Custo Fixo'], dtype=float)       #custo fixo
Ta = np.asarray(df1['Abre - horario'], dtype=float)   #tempo de abertura da janela
Tf = np.asarray(df1['Fecha - horario'], dtype=float)  #tempo de encerramento da janela
Tp = np.asarray(df1['Permanecia'], dtype=float)       #tempo de permanencia em um ponto
RS = np.asarray(df1['Avaliacao'], dtype=float)        #recompensa fixa
RO = np.asarray(df2, dtype=float)                     #recompensa por tempo de chegada
R_max = RS.max() + RO.max()                           #recompensa maxima
C = np.asarray(df3, dtype=float)                      #custo de viagem entre dois pontos
CV_max = C.max()                                      #custo de viagem maximo
CF_max = CF.max()                                     #custo fixo maximo
Td = np.asarray(df4, dtype=float)                     #tempo de deslocamento entre dois pontos
O = startingPoint                                     #ponto de origem
T_max = float(Tf[O])                                  #horario max de chagada em um ponto
B = 1000000                                           #valor auxiliar
N = len(df1)                                          #quantidade de pontos
D = 3                                                 #quantidade de dias para visita
K = len(df2.columns)                                  #quantidade de janelas de tempo para recompensa (tabela RO)

# %%
T_max
# Out:
# 24.0

# %% [markdown]
# ## Plot do grafo baseado no custo e no tempo

# %% [markdown]
# ### Custo de viagem

# %%
G = nx.from_numpy_matrix(C)
pos = nx.spring_layout(G)
pos_c = nx.kamada_kawai_layout(G, dist=C)

# %%
options = {
    'node_color': 'blue',
    'node_size': 100,
    'width': 1,
}
#nx.draw(G, pos=pos, **options)

# %%
options = {
    'node_color': 'blue',
    'node_size': 100,
    'width': 1,
}
nx.draw(G, pos=pos_c, **options)

# %% [markdown]
# ### Tempo de viagem

# %%
G2 = nx.from_numpy_matrix(Td)
pos = nx.spring_layout(G2)
pos_t = nx.kamada_kawai_layout(G2, dist=Td)

# %%
options = {
    'node_color': 'blue',
    'node_size': 100,
    'width': 1,
}
#nx.draw(G2, pos=pos, **options)

# %%
options = {
    'node_color': 'blue',
    'node_size': 100,
    'width': 1,
}
nx.draw(G2, pos=pos_t, **options)

# %% [markdown]
# ## Modelagem

# %% [markdown]
# $$
# \begin{aligned}
# Max \quad & \sum_{k \in K} \sum_{i \in N} \left( \frac{RO_{i,k} + RS_i}{R_{max}} \right)y_{i,k} - \sum_{i \in N} \sum_{j \in N : i \neq j} \left( \frac{C_{i,j}}{CV_{max}} + \frac{CF_i}{CF_{max}} \right)x_{i,j} \\
# S.A. \quad & x_{i,j} \leq 1, \forall i \in N, j \in N \\
#      \quad & \sum_{i \in N} x_{i,j} = \sum_{k \in K} y_{j,k}, \forall j \in N : i \neq j \\
#      \quad & \sum_{j \in N} x_{i,j} = \sum_{k \in K} y_{i,k}, \forall i \in N : i \neq j \\
#      \quad & \sum_{j \in N} x_{O,j} = D \\
#      \quad & \sum_{i \in N} x_{i,O} = D \\
#      \quad & \sum_{k \in K} y_{i,k} \leq 1, \forall i \in N \\
#      \quad & t_i \leq T_{max}, \forall i \in N \\
#      \quad & B - B\sum_{k \in K} y_{i,k} + t[i] \geq Ta[i], \forall i \in N \\
#      \quad & t[i] + Tp_i - B + B\sum_{k \in K}y_{i,k} \leq Tf_i, \forall i \in N \\
#      \quad & t_j - t_i - B*x_{i,j} \geq -B + Td_{i,j} + Tp_i, \forall i \in N, j \in N : i \neq O, j \neq O \\
#      \quad & t_i \leq B\sum_{k \in K}y_{i,k}, \forall i \in N \\
#      \quad & t_i < 1 + \sum_{k \in K}k*y_{i,k}, \forall i \in N \\
#      \quad & t_i \geq \sum_{k \in K}k*y_{i,k}, \forall i \in N
# \end{aligned}
# $$

# %% [markdown]
# ### Gurobi

# %%
model = gb.Model("PCTSP_gurobi")

x = model.addVars(N, N, vtype = gb.GRB.BINARY, name='x')
y = model.addVars(N, K, vtype = gb.GRB.BINARY, name ='y')
t = model.addVars(N, vtype = gb.GRB.CONTINUOUS, name ='t')

t[O] = 6 #partida da origem a partir das 6
for i in range(N):
    x[i,i] = 0

model.setObjective(gb.quicksum(gb.quicksum(((RO[i,k] + RS[i])/R_max)*y[i,k] for i in range(N)) for k in range(K)) - gb.quicksum(gb.quicksum((C[i,j]/CV_max + CF[i]/CF_max)*x[i,j] for i in range(N)) for j in range(N)), gb.GRB.MAXIMIZE) 

model.addConstrs(x[i,j] <= 1 for i in range(N) for j in range(N))
model.addConstrs(gb.quicksum(x[i,j] for j in range(N)) == gb.quicksum(y[i,k] for k in range(K)) for i in range(N) if i != O)
model.addConstrs(gb.quicksum(x[i,j] for i in range(N)) == gb.quicksum(y[j,k] for k in range(K)) for j in range(N) if j != O)
model.addConstr(gb.quicksum(x[O,j] for j in range(N)) == D)
model.addConstr(gb.quicksum(x[i,O] for i in range(N)) == D)
model.addConstrs(gb.quicksum(y[i,k] for k in range(K)) <= 1 for i in range(N))
model.addConstrs(t[i] <= T_max for i in range(N)) 
#model.addConstrs(t[i] + Tp[i] + Td[i,O] <= T_max for i in range(N))
model.addConstrs(B - B*gb.quicksum(y[i,k] for k in range(K)) + t[i] >= Ta[i] for i in range(N))
model.addConstrs(t[i] + Tp[i] - B + B*gb.quicksum(y[i,k] for k in range(K)) <= Tf[i] for i in range(N))
model.addConstrs(t[j] - t[i] - B*x[i,j] >= -B + Td[i,j] + Tp[i] for i in range(N) if i != O for j in range(N) if j != O)
#model.addConstrs(t[j] - t[O] - B*x[O,j] >= -B + Td[O,j] for j in range(N) if j != O)
model.addConstrs(t[i] <= B*gb.quicksum(y[i,k] for k in range(K)) for i in range(N))
model.addConstrs(t[i] + 0.1 <= gb.quicksum(k*y[i,k] for k in range(K)) + 1 for i in range(N))
model.addConstrs(t[i] >= gb.quicksum(k*y[i,k] for k in range(K)) for i in range(N))

# model.Params.timeLimit=3600 # TEMPO DE EXECUÇÃO
# model.Params.MIPGap = 0.1
model.optimize()
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 941 rows, 900 columns and 6032 nonzeros
# Model fingerprint: 0x05298b00
# Variable types: 20 continuous, 880 integer (880 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e-02, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e-01, 1e+06]
# Found heuristic solution: objective 1.0358333
# Presolve removed 846 rows and 726 columns
# Presolve time: 0.03s
# Presolved: 95 rows, 174 columns, 828 nonzeros
# Found heuristic solution: objective 1.8245833
# Variable types: 8 continuous, 166 integer (162 binary)
#
# Root relaxation: objective 7.470341e+00, 75 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    7.47034    0   28    1.82458    7.47034   309%     -    0s
# H    0     0                       2.2229789    7.47034   236%     -    0s
# H    0     0                       3.0579454    7.47034   144%     -    0s
# H    0     0                       4.4071839    7.47034  69.5%     -    0s
#      0     0    5.26794    0   21    4.40718    5.26794  19.5%     -    0s
#      0     0    5.10260    0    2    4.40718    5.10260  15.8%     -    0s
# H    0     0                       5.1026006    5.10260  0.00%     -    0s
#      0     0    5.10260    0    2    5.10260    5.10260  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 6
#   Implied bound: 2
#   Clique: 19
#   MIR: 7
#   StrongCG: 2
#   GUB cover: 3
#   Mod-K: 4
#   Network: 1
#   Relax-and-lift: 5
#
# Explored 1 nodes (164 simplex iterations) in 0.11 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 6: 5.1026 4.40718 3.05795 ... 1.03583
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.102600574713e+00, best bound 5.102600574713e+00, gap 0.0000%

# %%
print("função objetivo: ",str(round(model.ObjVal,2)))

for v in model.getVars():
    name = str(v.VarName)
    value = v.getAttr(gb.GRB.Attr.X)
    if value > 0:
        print(name +"="+ str(value))
# Out:
# função objetivo:  5.1
# x[3,5]=1.0
# x[4,3]=1.0
# x[4,9]=1.0
# x[4,10]=1.0
# x[5,4]=1.0
# x[7,8]=1.0
# x[8,4]=1.0
# x[9,7]=1.0
# x[10,12]=1.0
# x[12,4]=1.0
# y[3,12]=1.0
# y[4,6]=1.0
# y[5,16]=1.0
# y[7,12]=1.0
# y[8,18]=1.0
# y[9,7]=1.0
# y[10,8]=1.0
# y[12,15]=1.0
# t[3]=12.239999999967395
# t[5]=16.899999999999995
# t[7]=12.239999999967395
# t[8]=18.899999999999995
# t[9]=7.239999999967395
# t[10]=7.999999999999999
# t[12]=14.999999999999991

# %%
edges = []

for i in range(N):
    for j in range(N):
        if i != j and x[i,j].x > 0:
            edges.append((i,j))
                
edges
# Out:
# [(3, 5),
#  (4, 3),
#  (4, 9),
#  (4, 10),
#  (5, 4),
#  (7, 8),
#  (8, 4),
#  (9, 7),
#  (10, 12),
#  (12, 4)]

# %%
options = {
    'node_color': 'blue',
    'node_size': 300,
    'alpha': 0.5,
    'width': 1,
}

nx.draw(G, pos=pos_t, edgelist=edges, with_labels=True, arrows=True, **options)

# %% [markdown]
# ### Cplex

# %%
v_x = [(i,j) for i in range(N) for j in range(N)]
v_y = [(i,k) for i in range(N) for k in range(K)]
v_t = [i for i in range(N)]

mdl = CplexModel('PCTSP_cplex')

x = mdl.binary_var_dict(v_x, name='x')
y = mdl.binary_var_dict(v_y, name='y')
t = mdl.continuous_var_dict(v_t, name='t')

t[O] = 6 #partida da origem a partir das 6 am
for i in range(N):
    x[i,i] = 0

mdl.maximize(mdl.sum(mdl.sum(((RO[i,k] + RS[i])/R_max)*y[(i,k)] for i in range(N)) for k in range(K)) - mdl.sum(mdl.sum((C[i,j]/CV_max + CF[i]/CF_max)*x[(i,j)] for i in range(N)) for j in range(N)))

for i in range(N):
    for j in range(N):
        mdl.add_constraint(x[(i,j)] <= 1)
        
        if j != O:
            mdl.add_constraint(t[j] - t[i] - B*x[(i,j)] >= -B + Td[i,j] + Tp[i])
    
for i in range(N):
    mdl.add_constraint(mdl.sum(y[(i,k)] for k in range(K)) <= 1)
    mdl.add_constraint(t[i] <= T_max)
    mdl.add_constraint(B - B*mdl.sum(y[(i,k)] for k in range(K)) + t[i] >= Ta[i])
    mdl.add_constraint(t[i] + Tp[i] - B + B*mdl.sum(y[(i,k)] for k in range(K)) <= Tf[i])
    mdl.add_constraint(t[i] <= B*mdl.sum(y[(i,k)] for k in range(K)))
    mdl.add_constraint(t[i] + 0.1 <= mdl.sum(k*y[(i,k)] for k in range(K)) + 1)
    mdl.add_constraint(t[i] >= mdl.sum(k*y[(i,k)] for k in range(K)))
    
    if i != O:
        mdl.add_constraint(mdl.sum(x[(i,j)] for j in range(N)) == mdl.sum(y[(i,k)] for k in range(K)))
        mdl.add_constraint(mdl.sum(x[(j,i)] for j in range(N)) == mdl.sum(y[(i,k)] for k in range(K)))

mdl.add_constraint(mdl.sum(x[(O,j)] for j in range(N)) == D)
mdl.add_constraint(mdl.sum(x[(i,O)] for i in range(N)) == D)

# mdl.parameters.timelimit=120
# mdl.parameters.mip.strategy.branch=1
# mdl.parameters.mip.tolerances.mipgap=0.15

#cplex tem um limite de 1000 var e 1000 const
print('Variables =', mdl.number_of_variables)
print('Constraints =', mdl.number_of_constraints)
# Out:
# Variables = 900
# Constraints = 939

# %%
solucion = mdl.solve(log_output=True)
#print(mdl.export_to_string())
# Out:
# Version identifier: 22.1.0.0 | 2022-03-25 | 54982fbec
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# MIP Presolve eliminated 735 rows and 608 columns.
# MIP Presolve modified 2024 coefficients.
# Reduced MIP has 204 rows, 292 columns, and 1558 nonzeros.
# Reduced MIP has 274 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (4.43 ticks)
# Found incumbent of value 2.186695 after 0.01 sec. (6.18 ticks)
# Probing fixed 195 vars, tightened 11 bounds.
# Probing time = 0.02 sec. (0.77 ticks)
# Cover probing fixed 0 vars, tightened 3 bounds.
# Tried aggregator 3 times.
# MIP Presolve eliminated 154 rows and 207 columns.
# MIP Presolve modified 1 coefficients.
# Aggregator did 3 substitutions.
# Reduced MIP has 47 rows, 82 columns, and 394 nonzeros.
# Reduced MIP has 75 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (1.04 ticks)
# Probing fixed 51 vars, tightened 4 bounds.
# Probing time = 0.00 sec. (0.09 ticks)
# Tried aggregator 1 time.
# MIP Presolve eliminated 26 rows and 57 columns.
# Reduced MIP has 21 rows, 25 columns, and 115 nonzeros.
# Reduced MIP has 22 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.09 ticks)
# Probing time = 0.00 sec. (0.03 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 1 rows and 1 columns.
# Reduced MIP has 20 rows, 24 columns, and 110 nonzeros.
# Reduced MIP has 21 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.09 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# Clique table members: 9.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            2.1867       13.0050           494.73%
#       0     0        3.1010     3        2.1867        3.1010       13   41.81%
# *     0+    0                            3.0950        3.1010             0.19%
#       0     0        cutoff              3.0950                     13     ---
# Elapsed time = 0.09 sec. (8.96 ticks, tree = 0.01 MB, solutions = 2)
#
# Root node processing (before b&c):
#   Real time             =    0.09 sec. (8.99 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.09 sec. (8.99 ticks)

# %%
solucion.display()
# Out:
# solution for: PCTSP_cplex
# objective: 3.095
# x_3_5 = 1
# x_4_3 = 1
# x_4_10 = 1
# x_4_11 = 1
# x_5_4 = 1
# x_10_4 = 1
# x_11_4 = 1
# y_3_12 = 1
# y_4_6 = 1
# y_5_16 = 1
# y_10_17 = 1
# y_11_12 = 1
# t_3 = 12.240
# t_5 = 16.900
# t_10 = 17.000
# t_11 = 12.900

# %%
edges = []

for i in range(N):
    for j in range(N):
        if i != j and x[(i,j)].solution_value > 0:
            edges.append((i,j))
                
edges
# Out:
# [(3, 5), (4, 3), (4, 10), (4, 11), (5, 4), (10, 4), (11, 4)]

# %%
options = {
    'node_color': 'blue',
    'node_size': 300,
    'alpha': 0.5,
    'width': 1,
}

nx.draw(G, pos=pos_t, edgelist=edges, with_labels=True, arrows=True, **options)
